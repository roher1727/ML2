# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
# %matplotlib inline

# %%
def distancia_euclideana(punto1,punto2):
    distancia =  np.linalg.norm(punto1-punto2)
    return distancia

# %%
def prediccion(punto):
    for
# Out:
#   File "<ipython-input-71-566e76fc472d>", line 2
#     for
#         ^
# SyntaxError: invalid syntax

# %%
distancia_euclideana(np.array([1,2,3]),np.array([1,3,4]))
# Out:
# 1.4142135623730951

# %%
set_datos=load_iris()
set_entrenamiento=set_datos.data
set_objetivo=set_datos.target

# %%
elemento,cantidad=np.unique(set_objetivo,return_counts=True)
dict(zip(elemento,cantidad))
# Out:
# {0: 50, 1: 50, 2: 50}

# %%
a,b,c=np.array_split(set_entrenamiento,3)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
#ax.scatter(set_entrenamiento[:,0], set_entrenamiento[:,1],set_entrenamiento[:,2], c= 'red')
ax.scatter(a[:,0], a[:,1],a[:,2], c= 'red')

ax.scatter(b[:,0], b[:,1],b[:,2], c= 'green')

ax.scatter(c[:,0], c[:,1],c[:,2], c= 'blue')

# %%
set_entrenamiento[:,0]
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])
